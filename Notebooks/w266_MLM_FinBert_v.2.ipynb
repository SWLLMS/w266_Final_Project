# %% [markdown]
# ###Mounting of Google Drive

# %%
# This cell will authenticate you and mount your Drive in the Colab.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ###Instal/Load Packages & Libraries

# %%
# !pip install datasets -q
# !pip install -q transformers
# !pip install --quiet --upgrade accelerate
# !pip install evaluate -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.2/486.2 kB 7.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 13.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 23.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 17.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 30.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 56.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 93.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 73.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 4.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 kB 1.9 MB/s eta 0:00:00

# %%
import os, re
import time
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score, f1_score
from datasets import load_dataset
import evaluate
import math

## NN packages
import tensorflow as tf
from tensorflow import keras

# NLP packages
import torch
from transformers import AutoModelForMaskedLM, TFAutoModelForMaskedLM
from transformers import AutoTokenizer
from transformers import DataCollatorForLanguageModeling
from transformers import TrainingArguments, Trainer
from transformers import create_optimizer

# %%
import transformers

# %% [markdown]
# ###Loading in Datasets

# %%
dataset = load_dataset('csv', data_files={'train': '/content/drive/MyDrive/Colab Notebooks/w266/data/clean_train_data.csv',
                                          'eval': '/content/drive/MyDrive/Colab Notebooks/w266/data/clean_test_data.csv'}, encoding = "ISO-8859-1")
# Out:
# Downloading and preparing dataset csv/default to /root/.cache/huggingface/datasets/csv/default-4d94bd9b0ace3877/0.0.0/eea64c71ca8b46dd3f537ed218fc9bf495d5707789152eb2764f5c78fa66d59d...
# Downloading data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating eval split: 0 examples [00:00, ? examples/s]
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/csv/default-4d94bd9b0ace3877/0.0.0/eea64c71ca8b46dd3f537ed218fc9bf495d5707789152eb2764f5c78fa66d59d. Subsequent calls will reuse this data.
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
#loading in the training and test set
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['Unnamed: 0', 'text', 'label'],
#         num_rows: 16990
#     })
#     eval: Dataset({
#         features: ['Unnamed: 0', 'text', 'label'],
#         num_rows: 4117
#     })
# })

# %% [markdown]
# ###Metric Evaluations

# %%
def compute_metrics(eval_pred):
  predictions, labels = eval_pred.predictions, eval_pred.label_ids
  # Calculate metrics based on predictions and labels
  train_accuracy = accuracy_score(predictions, labels)

  # Use the validation dataset for evaluation
  val_predictions, val_labels = trainer.predict(eval_dataset)
  val_accuracy = accuracy_score(val_predictions, val_labels)

  f1 = f1_score(predictions, labels, average='micro')

  return {
        'train_accuracy': train_accuracy,
        'val_accuracy': val_accuracy,
        'f1_score': f1,
        }

# %%
metric = evaluate.load("accuracy")
# Out:
# Downloading builder script:   0%|          | 0.00/4.20k [00:00<?, ?B/s]

# %%
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    return metric.compute(predictions=predictions, references=labels)

# %%
from sklearn.metrics import accuracy_score

def compute_accuracy(pred):
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)
    return {"accuracy": accuracy_score(labels, preds)}

# %% [markdown]
# ###BERTbase (uncased) Fine Tuning
# This is the vanilla version of bert that we will continue to pretrain on our specific dataset.

# %% [markdown]
# ####Tokenizer Setup

# %%
tokenizer = AutoTokenizer.from_pretrained('yiyanghkust/finbert-pretrain')
model = TFAutoModelForMaskedLM.from_pretrained("yiyanghkust/finbert-pretrain", ignore_mismatched_sizes=True, from_pt=True)

# Loading finbert-pretrained
# finbert_base_model = TFAutoModel.from_pretrained('yiyanghkust/finbert-pretrain', ignore_mismatched_sizes=True, from_pt=True)
# finbert_base_tokenizer = BertTokenizer.from_pretrained('yiyanghkust/finbert-pretrain')
# Out:
# Downloading pytorch_model.bin:   0%|          | 0.00/442M [00:00<?, ?B/s]
# All PyTorch model weights were used when initializing TFBertForMaskedLM.
#
# All the weights of TFBertForMaskedLM were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertForMaskedLM for predictions without further training.

# %%
def tokenize_function(examples):
    result = tokenizer(examples["text"])
    if tokenizer.is_fast:
        result["word_ids"] = [result.word_ids(i) for i in range(len(result["input_ids"]))]
    return result

# %%
tokenized_dataset = dataset.map(
    tokenize_function, batched=True, remove_columns=["Unnamed: 0","text", "label"]
)
tokenized_dataset
# Out:
# Map:   0%|          | 0/16990 [00:00<?, ? examples/s]
# Map:   0%|          | 0/4117 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['input_ids', 'token_type_ids', 'attention_mask', 'word_ids'],
#         num_rows: 16990
#     })
#     eval: Dataset({
#         features: ['input_ids', 'token_type_ids', 'attention_mask', 'word_ids'],
#         num_rows: 4117
#     })
# })

# %%
chunk_size = 100

# %%
def group_texts(examples):
    # Concatenate all texts
    concatenated_examples = {k: sum(examples[k], []) for k in examples.keys()}

    # Compute length of concatenated texts
    total_length = len(concatenated_examples[list(examples.keys())[0]])

    # We drop the last chunk if it's smaller than chunk_size
    total_length = (total_length // chunk_size) * chunk_size

    # Split by chunks of max_len
    result = {
        k: [t[i : i + chunk_size] for i in range(0, total_length, chunk_size)]
        for k, t in concatenated_examples.items()
    }

    # Create a new labels column
    result["labels"] = result["input_ids"].copy()
    return result

# %%
lm_datasets = tokenized_dataset.map(group_texts, batched=True)
lm_datasets
# Out:
# Map:   0%|          | 0/16990 [00:00<?, ? examples/s]
# Map:   0%|          | 0/4117 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['input_ids', 'token_type_ids', 'attention_mask', 'word_ids', 'labels'],
#         num_rows: 4462
#     })
#     eval: Dataset({
#         features: ['input_ids', 'token_type_ids', 'attention_mask', 'word_ids', 'labels'],
#         num_rows: 1085
#     })
# })

# %%
# del dataset
# del tokenized_dataset

# %% [markdown]
# ### Fine-Tuning Bert Model

# %%
data_collator = DataCollatorForLanguageModeling(tokenizer=tokenizer, mlm=True, mlm_probability=0.15)

# %%
# Creating TF datasets

tf_train_dataset = model.prepare_tf_dataset(
    lm_datasets["train"],
    collate_fn=data_collator,
    shuffle=True,
    batch_size=32,
)

tf_eval_dataset = model.prepare_tf_dataset(
    lm_datasets["eval"],
    collate_fn=data_collator,
    shuffle=False,
    batch_size=32,
)
# Out:
# You're using a BertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.

# %%
# Creating lr schedule and compiling model
num_train_steps = len(tf_train_dataset)
optimizer, schedule = create_optimizer(
    init_lr=2e-5,
    num_warmup_steps=1_000,
    num_train_steps=num_train_steps,
    weight_decay_rate=0.01,
)
model.compile(optimizer=optimizer)

# %%
# Evaluating perplexity before training
eval_loss = model.evaluate(tf_eval_dataset)
print(f"Perplexity: {math.exp(eval_loss):.2f}")
# Out:
# 34/34 [==============================] - 9s 43ms/step - loss: 3.7784
# Perplexity: 43.75

# %%
# Training the model
model.fit(tf_train_dataset, validation_data=tf_eval_dataset, epochs=5)
# Out:
# Epoch 1/5
# 139/139 [==============================] - 56s 91ms/step - loss: 3.2975 - val_loss: 3.0285
# Epoch 2/5
# 139/139 [==============================] - 13s 91ms/step - loss: 2.9488 - val_loss: 2.8856
# Epoch 3/5
# 139/139 [==============================] - 13s 91ms/step - loss: 2.7686 - val_loss: 2.8132
# Epoch 4/5
# 139/139 [==============================] - 13s 91ms/step - loss: 2.6487 - val_loss: 2.6786
# Epoch 5/5
# 139/139 [==============================] - 13s 91ms/step - loss: 2.5469 - val_loss: 2.6043

# %%
# Evaluating perplexity after training
eval_loss = model.evaluate(tf_eval_dataset)
print(f"Perplexity: {math.exp(eval_loss):.2f}")
# Out:
# 34/34 [==============================] - 1s 41ms/step - loss: 2.6376
# Perplexity: 13.98

# %% [markdown]
# #### Saving model

# %%
# Checkpointing FinBert-MLM-Fit model
model.save_pretrained('/content/drive/MyDrive/Colab Notebooks/w266/Model Weights/FinBert-MLM-Fit')

# Checkpointing FinBert-MLM-Fit tokenizer
tokenizer.save_pretrained('/content/drive/MyDrive/Colab Notebooks/w266/Model Weights/FinBert-MLM-Fit-tokenizer')
# Out:
# ('/content/drive/MyDrive/Colab Notebooks/w266/Model Weights/FinBert-MLM-tokenizer/tokenizer_config.json',
#  '/content/drive/MyDrive/Colab Notebooks/w266/Model Weights/FinBert-MLM-tokenizer/special_tokens_map.json',
#  '/content/drive/MyDrive/Colab Notebooks/w266/Model Weights/FinBert-MLM-tokenizer/vocab.txt',
#  '/content/drive/MyDrive/Colab Notebooks/w266/Model Weights/FinBert-MLM-tokenizer/added_tokens.json',
#  '/content/drive/MyDrive/Colab Notebooks/w266/Model Weights/FinBert-MLM-tokenizer/tokenizer.json')
