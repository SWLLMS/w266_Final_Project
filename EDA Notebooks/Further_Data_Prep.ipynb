# %%
# This cell will authenticate you and mount your Drive in the Colab.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
train_data = pd.read_csv('/content/drive/MyDrive/W266/data/clean_train_data.csv')
test_data = pd.read_csv('/content/drive/MyDrive/W266/data/clean_test_data.csv')

# %%
test_data = test_data.drop('Unnamed: 0', axis=1)

# %%
test_data.to_csv('/content/drive/MyDrive/W266/test_data.csv', index=False)

# %%
train_data
# Out:
#        Unnamed: 0                                               text  label
# 0               0  Here are Thursday's biggest analyst calls: App...      0
# 1               1  Buy Las Vegas Sands as travel to Singapore bui...      0
# 2               2  Piper Sandler downgrades DocuSign to sell, cit...      0
# 3               3  Analysts react to Tesla's latest earnings, bre...      0
# 4               4  Netflix and its peers are set for a ‘return to...      0
# ...           ...                                                ...    ...
# 16985       16985  KfW credit line for Uniper could be raised to ...      3
# 16986       16986  KfW credit line for Uniper could be raised to ...      3
# 16987       16987  Russian   sells 1 bln roubles at one-year repo...      3
# 16988       16988  Global ESG bond issuance posts H1 dip as supra...      3
# 16989       16989  Brazil's Petrobras says it signed a $1.25 bill...      3
#
# [16990 rows x 3 columns]

# %%
train_data = train_data.drop('Unnamed: 0', axis=1)

# %%
train_data
# Out:
#                                                     text  label
# 0      Here are Thursday's biggest analyst calls: App...      0
# 1      Buy Las Vegas Sands as travel to Singapore bui...      0
# 2      Piper Sandler downgrades DocuSign to sell, cit...      0
# 3      Analysts react to Tesla's latest earnings, bre...      0
# 4      Netflix and its peers are set for a ‘return to...      0
# ...                                                  ...    ...
# 16985  KfW credit line for Uniper could be raised to ...      3
# 16986  KfW credit line for Uniper could be raised to ...      3
# 16987  Russian   sells 1 bln roubles at one-year repo...      3
# 16988  Global ESG bond issuance posts H1 dip as supra...      3
# 16989  Brazil's Petrobras says it signed a $1.25 bill...      3
#
# [16990 rows x 2 columns]

# %%
train_dataset, eval_dataset = train_test_split(train_data, test_size=0.2, random_state=10)

# %%
train_dataset
# Out:
#                                                     text  label
# 6453   Chinese banks are expected to hold their main ...      1
# 8854   Copper prices are signaling that investors are...     10
# 11080  UK Demand For Homes Falls For A Third Month As...     14
# 1383   SINOVAC Initiates Clinical Trial for Its Quadr...      2
# 3594   Electric-vehicle maker Rivian confirmed plans ...      2
# ...                                                  ...    ...
# 4829   Global Indemnity Group, LLC Second Quarter 202...      5
# 10201  The consensus view among economists and invest...     14
# 9372   Three Arrows liquidators won permission to sub...     12
# 7291   Bank SEB's quarterly net profit beats estimate...      7
# 7293   Poundland owner Pepco posts 17% rise in quarte...      7
#
# [13592 rows x 2 columns]

# %%
eval_dataset
# Out:
#                                                     text  label
# 11783  Asia-Pacific stocks set to trade mixed ahead o...     15
# 6581   Ukraine’s central bank devalues the official h...      1
# 2859   $MYMD - MyMD to collaborate with leading U.S. ...      2
# 9564   Novaria Group Signs Agreement to Acquire Stroc...     13
# 15655  $CCI - Crown Castle: Critical Nationwide Infra...     18
# ...                                                  ...    ...
# 6902   Burberry Group PLC same-store sales rise only ...      7
# 11468  A broader sweep of US cities crossed the 10% i...     14
# 10854  Ukraine and Russia are close to agreeing a dea...     14
# 9719   $BMY $TPTX - Bristol Myers extends tender offe...     13
# 11257  Britain is moving forward with policies to ram...     14
#
# [3398 rows x 2 columns]

# %%
train_labels = train_dataset['label']
eval_labels = eval_dataset['label']

# %%
train_label_count = train_labels.value_counts()
train_label_count
# Out:
# 2     2848
# 18    1682
# 14    1464
# 9     1223
# 5      787
# 16     779
# 1      666
# 19     664
# 7      506
# 6      427
# 15     412
# 17     405
# 12     394
# 13     381
# 4      290
# 3      250
# 0      203
# 8      130
# 10      50
# 11      31
# Name: label, dtype: int64

# %%
eval_label_count = eval_labels.value_counts()
eval_label_count
# Out:
# 2     697
# 18    436
# 14    358
# 9     334
# 16    206
# 5     200
# 1     171
# 19    159
# 7     118
# 6      97
# 12     93
# 17     90
# 13     90
# 15     89
# 3      71
# 4      69
# 0      52
# 8      36
# 10     19
# 11     13
# Name: label, dtype: int64

# %%
first_half_train_data, sec_half_train_data = train_test_split(train_dataset, test_size=0.5, random_state=10)

# %%
first_half_train_data
# Out:
#                                                     text  label
# 1922   Marathon Asset Management Ltd UK Regulatory An...      2
# 3763   Swatch Group upbeat as China comes out of lock...      2
# 15067  $ARE - Alexandria: An Excellent Bargain You Do...     18
# 12996  Crunch time has finally arrived for Joe Biden’...     16
# 8837   From Breakingviews - Raging crisis puts Sri La...      9
# ...                                                  ...    ...
# 2750   $CLSK - CleanSpark expands bitcoin mining capa...      2
# 12141  S&amp;P 500 Is At A Critical Juncture; Expecti...     15
# 7672   The global competition with China is also show...      9
# 9726   $RARE - Ultragenyx to acquire GeneTx after pro...     13
# 12000  EURO STOXX INDEX DOWN 0.90%; EURO ZONE BLUE CH...     15
#
# [6796 rows x 2 columns]

# %%
sec_half_train_data
# Out:
#                                                     text  label
# 2258   CARMILA: Resources Devoted to the Liquidity Co...      2
# 201    $SILK - Silk Road Medical falls after Citigrou...      0
# 2438   Meta has terminated its contract with a longti...      2
# 12763  NEW: Italian Prime Minister Mario Draghi will ...     16
# 11741  EU edges closer to ending 'too-big-to-fail' ba...     14
# ...                                                  ...    ...
# 10796  UK TRANSPORT SECRETARY GRANT SHAPPS SAYS DEFEN...     14
# 13108  U.S. HOUSE DEMOCRATIC CAUCUS CHAIR JEFFRIES: S...     16
# 6822   $GTE: Gran Tierra Energy reports Q2 production...      7
# 12093  The S&amp;P and Nasdaq lost nearly 1%. Oil pri...     15
# 13125  The UK government should ‘urgently’ strike an ...     16
#
# [6796 rows x 2 columns]

# %%
first_half_train_labels = first_half_train_data['label']
sec_half_train_labels = sec_half_train_data['label']

# %%
first_half_count = first_half_train_labels.value_counts()
first_half_sorted_counts = first_half_count.sort_index()
first_half_sorted_counts
# Out:
# 0       96
# 1      332
# 2     1473
# 3      121
# 4      155
# 5      384
# 6      234
# 7      262
# 8       69
# 9      628
# 10      24
# 11      16
# 12     187
# 13     187
# 14     736
# 15     217
# 16     364
# 17     189
# 18     809
# 19     313
# Name: label, dtype: int64

# %%
sec_half_count = sec_half_train_labels.value_counts()
sec_half_sorted_counts = sec_half_count.sort_index()
sec_half_sorted_counts
# Out:
# 0      107
# 1      334
# 2     1375
# 3      129
# 4      135
# 5      403
# 6      193
# 7      244
# 8       61
# 9      595
# 10      26
# 11      15
# 12     207
# 13     194
# 14     728
# 15     195
# 16     415
# 17     216
# 18     873
# 19     351
# Name: label, dtype: int64

# %%
first_half_train_data.to_csv('/content/drive/MyDrive/W266/first_half_train.csv', index=False)
sec_half_train_data.to_csv('/content/drive/MyDrive/W266/sec_half_train.csv', index=False)

# %%
train_dataset.to_csv('/content/drive/MyDrive/W266/trainMLM.csv', index=False)
eval_dataset.to_csv('/content/drive/MyDrive/W266/evalMLM.csv', index=False)
